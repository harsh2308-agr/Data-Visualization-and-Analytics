# %% [markdown]
# ## Name- Harsh Agrawal CSE SEM-7 Shift-2 RollNo-43
# ### DVA LAB Practical No-3

# %% [markdown]
# ### Aim: Market basket analysis using apriori algorithm in Python [Association rule mining]

# %% [markdown]
# PART(B): Perform Market basket analysis using the apriori algorithm on
# Market_Basket_Optimisation.csv dataset.
# About the dataset: The dataset contains the items bought by a customer i.e. each row
# represents one customer.
# Use mlxtend library to import apriori algorithm.

# %%
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# ### Do as directed:

# %% [markdown]
# 1. Import the dataset using pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("B_43_Harsh Agrawal - Market_Basket_Optimisation - B_43_Harsh Agrawal - Market_Basket_Optimisation.csv", header=None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %% [markdown]
# 2. State the number of rows and columns in the dataset. What do rows and columns
# represent about the dataset?

# %% [markdown]
# Answer--> The number of rows in the dataset are 7500 and the number of coloumns are 20

# %% [markdown]
# 3. Replace all the nan values with &#39; &#39; [blank]

# %%
df = df.fillna(" ")
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs
# 2           chutney
# 3            turkey            avocado
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken
# 7499       escalope          green tea
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# 0     green grapes  whole weat flour  yams  cottage cheese  energy drink
# 1
# 2
# 3
# 4        green tea
# ...            ...               ...   ...             ...           ...
# 7496
# 7497     magazines         green tea
# 7498
# 7499
# 7500
# ...

# %% [raw]
# Using the fillna function all the null values present in the dataframe are replaced with the blank sapce as specified.

# %% [markdown]
# 4. Find the total number of unique products available

# %%
product=[]

for j in range (0,df.shape[1]):
    for i in range(0,df.shape[1]):
        if str(df.values[i,j]) not in product:
            product.append(str(df.values[i,j]))
print(product)
print("---------------------------------------------------")
print("Total number of unique products are:",len(product))
# Out:
# ['shrimp', 'burgers', 'chutney', 'turkey', 'mineral water', 'low fat yogurt', 'whole wheat pasta', 'soup', 'frozen vegetables', 'french fries', 'eggs', 'cookies', 'spaghetti', 'meatballs', 'almonds', ' ', 'avocado', 'milk', 'light cream', 'pet food', 'champagne', 'salmon', 'chocolate', 'fresh tuna', 'energy bar', 'shallot', 'green tea', 'chicken', 'tomatoes', 'honey', 'vegetables mix', 'whole wheat rice', 'green grapes', 'cooking oil', 'oil', 'protein bar', 'whole weat flour', 'black tea', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'extra dark chocolate', 'salad', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']
# ---------------------------------------------------
# Total number of unique products are: 48

# %% [markdown]
# 5. Represent using appropriate visualization, the unique products vs the number of times
# they are purchased. [Restrict to top 10 items].

# %%
df[0].value_counts().head(40).plot.bar(figsize=(13,5), color='red')
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %% [markdown]
# The above plot shows the unique items present in the dataframe where the name of product is dispalyed along the x axis and the quantity of the particualar product is displayed along the y axis.

# %% [markdown]
# 6. Convert the data frame into a list of a list where each inner list represents a
# transaction. For example, all items of row 1 will be present in the first list inside the
# outer list.

# %%
l=df.values.tolist()
for i in l:
    print(i,"\n")
# Out:
# ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']
#
# ['burgers', 'meatballs', 'eggs', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# ['chutney', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# ['turkey', 'avocado', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# ['low fat yogurt', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
#
# ...

# %% [raw]
# The data frame is converted into a list of a list where each inner list represents a transaction.Here all items of row 1 will be present in the first list inside the outer list.

# %% [markdown]
# 7. Transform the dataset for the Aprori algorithm: Encode the data such that it contains
# True and False / 0 and 1. The columns are the item names and rows will contain if
# that item is present or not.

# %%
from mlxtend.preprocessing import TransactionEncoder
encoder = TransactionEncoder().fit(l)
onehot = encoder.transform(l)
onehot = pd.DataFrame(onehot, columns = encoder.columns_)
onehot
# Out:
#              almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0     False     True               True      False     True        False
# 1      True    False              False      False    False        False
# 2      True    False              False      False    False        False
# 3      True    False              False      False     True        False
# 4      True    False              False      False    False        False
# ...     ...      ...                ...        ...      ...          ...
# 7496   True    False              False      False    False        False
# 7497   True    False              False      False    False        False
# 7498   True    False              False      False    False        False
# 7499   True    False              False      False    False        False
# 7500   True    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# ...

# %% [raw]
# The given dataset is transformed as per the requirement of the apriori algorithm where the values are converted to true and false accordingly as per required. It is trueif present else false.The function Transaction Encoder is ued for the task and the list of list is passed as a parameter.

# %% [markdown]
# 8. Find the frequent item set by applying the Aprori algorithm. [use min support as
# min_support=0.01]. Draw a conclusion based on the output received.

# %%
# Compute frequent itemsets using the Apriori algorithm
frequent_itemsets = apriori(onehot, min_support = 0.01, max_len = 3, use_colnames = True)

frequent_itemsets
# Out:
#       support                                 itemsets
# 0    0.999867                                      ( )
# 1    0.020397                                (almonds)
# 2    0.033329                                (avocado)
# 3    0.010799                         (barbecue sauce)
# 4    0.014265                              (black tea)
# ..        ...                                      ...
# 493  0.011065       (ground beef, mineral water, milk)
# 494  0.017064  (ground beef, mineral water, spaghetti)
# 495  0.015731         (mineral water, milk, spaghetti)
# 496  0.010265    (mineral water, olive oil, spaghetti)
# 497  0.011465     (pancakes, mineral water, spaghetti)
#
# [498 rows x 2 columns]

# %% [markdown]
# 9. Represent using appropriate visualization, a few groups of item sets with their
# meaning

# %%
x=[float(i) for i in frequent_itemsets['support'][:10]]
y=[str(i) for i in frequent_itemsets['itemsets'][:10]]
plt.bar(y,x, color="blue")
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %% [raw]
# A few of the itemsets are displayed with the group of items clubed together on xaxis and the support value is plotted on y axis

# %% [markdown]
#  10. Find the association rules among the items/group of items that have support greater
# than the min support. Use metric as &quot;confidence&quot; and min_threshold=0.2, and display
# the results sorted by lift.

# %%
from mlxtend.frequent_patterns import association_rules
frequent_itemsets = apriori(onehot, min_support = 0.01, 
                            max_len = 2, use_colnames = True)

rules = association_rules(frequent_itemsets, 
                            metric = "confidence", 
                            min_threshold = 0.2)


prod_list=rules.sort_values('lift')
prod_list
# Out:
#           antecedents          consequents  antecedent support  \
# 133        (escalope)      (mineral water)            0.079323
# 149       (green tea)      (mineral water)            0.132116
# 74             (yams)                  ( )            0.011465
# 0           (almonds)                  ( )            0.020397
# 70   (vegetables mix)                  ( )            0.025730
# ..                ...                  ...                 ...
# 156       (spaghetti)        (ground beef)            0.174110
# 166            (soup)               (milk)            0.050527
# 143          (shrimp)  (frozen vegetables)            0.071457
# 145        (tomatoes)  (frozen vegetables)            0.068391
# 151   (herb & pepper)        (ground beef)            0.049460
#
#      consequent support   support  confidence      lift  leverage  conviction
# 133            0.238368  0.017064    0.215126  0.902495 -0.001844    0.970387
# ...

# %% [raw]
# The association rules among the items/group of items that have support greater than the min support are displayed here the metric used is confidence and the min_support is kept as 0.2.
# The rules are created such that antecedent gives consequent means if the antecendents are purchsed then the chances of purchasing the consequents increases.

# %% [markdown]
# 11. Find the various products that must be placed together to maximize the profit for the
# dataset specified.

# %%
freq=[]
for i in range(len(prod_list['lift'])):
    if prod_list['lift'][i]>1 :
        freq.append([prod_list['antecedents'][i],prod_list['consequents'][i]])
        
freq
# Out:
# [[frozenset({'barbecue sauce'}), frozenset({' '})],
#  [frozenset({'black tea'}), frozenset({' '})],
#  [frozenset({'body spray'}), frozenset({' '})],
#  [frozenset({'brownies'}), frozenset({' '})],
#  [frozenset({'burgers'}), frozenset({' '})],
#  [frozenset({'butter'}), frozenset({' '})],
#  [frozenset({'cake'}), frozenset({' '})],
#  [frozenset({'carrots'}), frozenset({' '})],
#  [frozenset({'cereals'}), frozenset({' '})],
#  [frozenset({'champagne'}), frozenset({' '})],
#  [frozenset({'chicken'}), frozenset({' '})],
#  [frozenset({'chocolate'}), frozenset({' '})],
#  [frozenset({'cider'}), frozenset({' '})],
#  [frozenset({'cookies'}), frozenset({' '})],
#  [frozenset({'cooking oil'}), frozenset({' '})],
#  [frozenset({'eggplant'}), frozenset({' '})],
#  [frozenset({'eggs'}), frozenset({' '})],
#  [frozenset({'energy bar'}), frozenset({' '})],
#  [frozenset({'escalope'}), frozenset({' '})],
#  [frozenset({'extra dark chocolate'}), frozenset({' '})],
# ...

# %% [raw]
# Lift-->This says how likely item Y is purchased when item X is purchased, while controlling for how popular item Y is. In Table 1, the lift of {apple -> beer} is 1,which implies no association between items. A lift value greater than 1 means that item Y is likely to be bought if item X is bought, while a value less than 1 means that item Y is unlikely to be bought if item X is bought.
#
# Lift if the measure which is used to decide if two itemsets are applicable to be kept together hence the itemsets are clubbed to be kept together based on the value of lift

# %% [markdown]
# 12. Change the threshold and specify its impact.

# %%
from mlxtend.frequent_patterns import association_rules
frequent_itemsets = apriori(onehot, min_support = 0.01, 
                            max_len = 2, use_colnames = True)

rules = association_rules(frequent_itemsets, 
                            metric = "confidence", 
                            min_threshold = 1)


prod_list=rules.sort_values('lift')
prod_list
# Out:
#                antecedents consequents  antecedent support  \
# 0         (barbecue sauce)         ( )            0.010799
# 32           (light cream)         ( )            0.015598
# 33            (light mayo)         ( )            0.027196
# 34             (magazines)         ( )            0.010932
# 35             (meatballs)         ( )            0.020931
# 36                (melons)         ( )            0.011998
# 37                  (milk)         ( )            0.129583
# 38                  (mint)         ( )            0.017464
# 39               (muffins)         ( )            0.024130
# 40  (mushroom cream sauce)         ( )            0.019064
# 41           (nonfat milk)         ( )            0.010399
# 42                   (oil)         ( )            0.023064
# 43              (pancakes)         ( )            0.095054
# 31              (hot dogs)         ( )            0.032396
# 44       (parmesan cheese)         ( )            0.019864
# ...

# %%
from mlxtend.frequent_patterns import association_rules
frequent_itemsets = apriori(onehot, min_support = 0.01, 
                            max_len = 2, use_colnames = True)

rules = association_rules(frequent_itemsets, 
                            metric = "confidence", 
                            min_threshold = 0)


prod_list=rules.sort_values('lift')
prod_list
# Out:
#              antecedents          consequents  antecedent support  \
# 256               (eggs)            (cookies)            0.179709
# 257            (cookies)               (eggs)            0.080389
# 271               (eggs)           (escalope)            0.179709
# 270           (escalope)               (eggs)            0.079323
# 213            (cookies)          (chocolate)            0.080389
# ..                   ...                  ...                 ...
# 361             (shrimp)  (frozen vegetables)            0.071457
# 364  (frozen vegetables)           (tomatoes)            0.095321
# 365           (tomatoes)  (frozen vegetables)            0.068391
# 388        (ground beef)      (herb & pepper)            0.098254
# 389      (herb & pepper)        (ground beef)            0.049460
#
#      consequent support   support  confidence      lift  leverage  conviction
# 256            0.080389  0.010532    0.058605  0.729019 -0.003915    0.976860
# ...

# %% [raw]
# Incresing threshold results in more strict rules thus only most frequent combinations are choosen where as decreasing can cause independent items in the list

# %% [markdown]
# 13. Consider some random antecedents and consequents and find if it will be good to
# place them nearby to increase sales.

# %%
import random
a=random.randint(0,len(prod_list["lift"]))

print("The Radom antecedent is {} and random consequent is {} it's lift is {} ".format(prod_list['antecedents'][i], prod_list['consequents'][i], prod_list['lift'][i]))
# Out:
# The Radom antecedent is frozenset({'cake'}) and random consequent is frozenset({'pancakes'}) it's lift is 1.5399834834280655

# %% [raw]
# The random itemsets picked are cakes and pancakes and the value of lift comes out to be 1.5399834834280655 which is found to be greater than 1 which indicates that they can be kept together
