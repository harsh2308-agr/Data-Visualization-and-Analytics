# %% [markdown]
# # Name- Harsh Agrawal CSE SEM-7 Shift-2 RollNo-43
#
# # PRACTICAL NO-- 2 DVA

# %% [markdown]
# ## Aim: Data Visualization and preprocessing on the given data set in Python.
# ### PART (A): Data Visualization using Matplotlib
# ### Write a program to visualize Company Sales Data &amp; perform the following task (CSV file will be provided)
# #### Note: For all the plots, specify the title &amp; labels by setting appropriate properties &amp; also write the detail analysis for all the plots.
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Do as Directed On Company Sales Data:
# ### 1. Read Total profit of all months and show it using a line plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("B_43_Harsh Agrawal - company_sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# Inference- Python libraries pandas and matplotlib have been imported and company_sales_data csv file has been read and displayed

# %%
x = df['month_number'].tolist()
y = df['total_profit'].tolist()

plt.plot(x,y, marker='d')
plt.title("Total profit of all months")
plt.xlabel("Months")
plt.ylabel("Total Profit")
plt.xticks(x)
plt.show()

# %% [markdown]
# Inference- The above plotted line chart demonstartes a line chart between total profit vs month number. <br>
# A line graph is useful for displaying data or information that changes continuously over time. The line shows a change in data over time.<br>
# Second month has the lowest total profit and eleventh month has the heighet total profit. <br>
# A drastic spike has been observed on sixth month.

# %% [markdown]
# ### 2. Read all product sales data and show it using a multiline plot

# %%
x = df['month_number'].tolist()

fc = df['facecream'].tolist()
fw = df['facewash'].tolist()
tp = df['toothpaste'].tolist()
bs = df['bathingsoap'].tolist()
s  = df['shampoo'].tolist()
m  = df['moisturizer'].tolist()

plt.plot(x,fc,x,fw,x,tp,x,bs,x,s,x,m,marker='o',alpha=0.5)
plt.legend(['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer'],bbox_to_anchor =(1, 1))
plt.xticks(x)
plt.title("Product sales last year")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Inference-
#
# 1.  A line chart has been plotted for sales and month number for all the product indiuvidually.
# 2.  Bathing soap has the heighest sale and the moisturizer has the lowest sale.
#
# 1.   The sale increased by month number 8. Market basket analysis can be applied to increse the sale of products such as moisturizer and shampoo by keeping them with the related products such as bathing soap.
# 2.   For face cream, moisturizer and shampoo the sale is observed to be relatively constant

# %% [markdown]
# ### 3. Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).

# %%
x = df['month_number'].tolist()

fc = df['facecream'].tolist()
fw = df['facewash'].tolist()
tp = df['toothpaste'].tolist()
bs = df['bathingsoap'].tolist()
s  = df['shampoo'].tolist()
m  = df['moisturizer'].tolist()

plt.plot(x,fc,x,fw,x,tp,x,bs,x,s,x,m,marker='o',alpha=0.5)
plt.legend(['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer'],bbox_to_anchor =(1, 1))
plt.xticks(x)
plt.title("Product sales last year")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# Inerence observed is same as above

# %% [markdown]
# ### 4. Read toothpaste sales data of each month and show it using a scatter plot.

# %%
x  = df['month_number'].tolist()
tp = df['toothpaste'].tolist()

plt.scatter(x,tp)
plt.title("Toothpaste sales data of each month")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.xticks(x)

plt.show()

# %% [markdown]
# 1.   Inference- Toothpaste sale has has been plotted along with the month number using a scatter plot.
# 2.   The sale of the product gradually increased along with the month number. The heighest and lowest sales has been observed for the month nnumber 10 and 3 respectively.

# %% [markdown]
# ### 5. Read facecream and facewash product sales data and show it using the bar chart.

# %%
x  = df['month_number'].tolist()
fc = df['facecream'].tolist()
fw = df['facewash'].tolist()

plt.bar(x,fc,color='r')
plt.bar(x,fw,color='black')
plt.legend(['Facecream','Facewash'],loc='upper left',bbox_to_anchor=(1,1))
plt.title("Facecream and Facewash product sales")
plt.xlabel('Month')
plt.ylabel('sales')
plt.xticks(x)
plt.show()

# %% [markdown]
# 1. Inference- From the company sales data sales of facecream and face wash has een plotted using a bar chart. Both the products have been plotted on the same bar.
# 2.   Heighest sale for the facewash has been observed on month 10 and lowest sale has been observed on month six. Similarly for face cream it is month numer 8 and 10.
#
# 1.   On month 10 both the prodcts showd approximately equal sale.

# %% [markdown]
# ### 6. Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk

# %%
x  = df['month_number'].tolist()
bs = df['bathingsoap'].tolist()

plt.bar(x,bs,color='g')
plt.title("Sales data of bathing soap")
plt.xlabel("Number of month")
plt.ylabel("Sales")
plt.xticks(x)

plt.savefig('Bathingsoap sale.png')
plt.show()

# %% [markdown]
# 1.   Bar chart has been ploted for the sale of athing soap with month number on x axis and sales on y axis. Heighest and lowest sales hab been observed on month number 12 and 2 respectively.
# 2.   The plotted bar chart can be saved to the device as an image using the savefig funcion.

# %% [markdown]
# ### 7. Read the total profit of each month and show it using the histogram to see the most common profit ranges

# %%
x  = df['month_number'].tolist()
tp = df['total_profit'].tolist()
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]

plt.hist(tp, profit_range)
plt.xlabel('Profit Range')
plt.ylabel('Actual Profit')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %% [markdown]
# 1.  A bar chart is plotted for total profit for each month. The plot is created as for actual profit earned vs the profit range.

# %% [markdown]
# ### 8. Calculate total sale data for last year for each product and show it using a Pie chart.

# %%
fc = df['facecream'].sum()
fw = df['facewash'].sum()
tp = df['toothpaste'].sum()
bs = df['bathingsoap'].sum()
s  = df['shampoo'].sum()
m  = df['moisturizer'].sum()

data = [fc,fw,tp,bs,s,m]
labels = ["Facecream", "Facewash", "Toothpaste", "Bathing Soap", "Shampoo", "Moisturizer"]

plt.pie(data,labels=labels)
plt.legend(bbox_to_anchor=(2,1))
plt.show()

# %% [markdown]
# 1.   Total sale data has been calculated for the last year for each product and is plotted on a pie chart.
# 2.   Heighest sale has been plotted for bathing soap and lowest sale has been observed for moisturizer and facewash.

# %% [markdown]
# ### 9. Read Bathing soap facewash of all months and display it using the Subplot

# %%
x = df['month_number'].tolist()
bs = df['bathingsoap'].tolist()
fw = df['facewash'].tolist()

plt.figure(figsize=(14, 5)) 

plt.subplot(1,2,1)
plt.plot(x,bs,color='g',marker="o")
plt.xticks(x)
plt.title("Bathing Soap sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.subplot(1,2,2)
plt.plot(x,fw,color='r',marker="s")
plt.xticks(x)
plt.title("Facewash sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %% [markdown]
# 1.   Bathing soap and face wash sales data has been plotted for each month using a lie chart. The chart is displayed using a subplot with 1 row and 2 coloumns.
# 2.   It is obserevd that bathing soap has more sale than facewash. Heighest and lowest sale for the bathing soap was in month 12 and 2 which was 14000 and 6000 respictively. Similarly for facewash it is month 11 and 7 with sales as 2200 and 200(approximately) respectively.

# %% [markdown]
# ### 10. Read all product sales data and show it using the stack plot.

# %%
x = df['month_number'].tolist()

fc = df['facecream'].tolist()
fw = df['facewash'].tolist()
tp = df['toothpaste'].tolist()
bs = df['bathingsoap'].tolist()
s  = df['shampoo'].tolist()
m  = df['moisturizer'].tolist()

plt.figure(figsize=(14,5))
plt.stackplot(x,fc,fw,tp,bs,s,m)
plt.legend(['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer'],bbox_to_anchor =(0, 0))
plt.xticks(x)
plt.title("Product sales last year")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# 1.  A stack plot is created for product sales for last year. Stackplot is used to draw a stacked area plot. It displays the complete data for visualization
# 2.  In the plotted stackplot the maximum area is captured for bathing soap and minimum area has veen captured by facewash.

# %% [markdown]
# ### 11. Get total profit of all months and show line plot with the following Style properties.
# ### 12. Generated line plot must include following Style properties:
#  ##### Line Style dotted and Line-color should be red
#  ##### Show legend at the lower right location.
#  ##### X label name = Month Number
#  ##### Y label name = Sold unit’s number
#  ##### Add a circle marker.
#  ##### Line marker color as red
#  ##### Line width should be 3

# %%
x = df['month_number'].tolist()
tp = df['total_profit'].tolist()

plt.plot(x, tp, linestyle="--", marker='o', markerfacecolor='r', linewidth=3)
plt.legend(["Total profit"],loc='lower right')
plt.xlabel('Month Number')
plt.ylabel('Sold unit\'snumber')

plt.show()

# %% [markdown]
# 1.  The total profit for all the months has been plotted using a line chart. Heighest and lowest profit has been observed in month 12 and 2 respectively.
# 2.   A circular marker has been added to show the corect value of nnumber of sold units.

# %% [markdown]
# #### -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## Do as Directed:

# %% [markdown]
# ### 1. Draw a scatter graph of any 50 random values of x and y axis.

# %%
import random

x = []
y = []

for _ in range (50):
    x.append(random.randint(1,10000))
for _ in range (50):
    y.append(random.randint(1,10000))

plt.scatter(x,y)
plt.title("50 random values of x and y axis")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# A scatter plot has been drawn for any 50 random values.

# %% [markdown]
# ### 2. Create data using numpy array from 0 to 5 with a gap of 0.01 for x axis, consider y axis as square values of x and show the line graph with grid lines

# %%
import numpy as np
x = np.arange(0,5,0.01) 
y = [i*i for i in x]

plt.plot(x,y)
plt.grid(axis='x')
plt.grid(axis='y')
plt.title("y axis as square values of x")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.show()

# %% [markdown]
#  A numpy array has been created for values ranging from 0 to 5 with a gap of 0.01 and y axis shows the square of x values.

# %% [markdown]
# ### 3. Create linear, square and cube data points and create a multiline graph for the same with title to graph and both axis.

# %%
import numpy as np
x = np.arange(0,5,1)
y = [i*i for i in x]
z = [i*i*i for i in x]

plt.plot(x,x,x,y,x,z)
plt.title("linear, square and cube data points")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(["Linear","Square","Cube"])
plt.xticks(x)
plt.show()

# %% [markdown]
# A multiline graph has been created with three lines with linear, square and cube data values.

# %% [markdown]
# ### 4. The dataset given, records data of city temperatures over the years’2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

# %%
df0 =pd.read_csv("CityTemps.csv")
x=df0["Moscow"]

y=df0["San Francisco"]

plt.hist(x, len(x), facecolor='blue', alpha=0.5)
plt.hist(y, len(y), facecolor='red', alpha=0.5)

plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.title("Temperatures of Mosco and San Francisco")

plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='right') # Rotate Axis Labels

plt.show()

# %% [markdown]
# #### ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
